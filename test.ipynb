# %%
from audio_processing import *

# %%
song = Audio("sample_input/telhados.wav")
song.load()
song_resampled = song.resample(sample_rate=250)
song_resampled.make_spectogram().plot.contours(['bone', 'BuPu'], save=False)
# Out:
# Audio file loaded, sample rate: 44100
# Audio file resampled, old sample rate: 44100, new sample rate: 250
# time bins:  312
# freq bins:  513

# %%
song = Audio("sample_input/telhados.wav")
song.load()
song_resampled = song.resample(940)
song_resampled.make_spectogram().plot.contours(['bone', 'BuPu'], save=True)
# Out:
# Audio file loaded, sample rate: 44100
# Audio file resampled, old sample rate: 44100, new sample rate: 940
# time bins:  1172
# freq bins:  513
