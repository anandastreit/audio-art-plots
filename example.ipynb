# %%
from audio_processing import *
from color_utils import *

# %%
song = Audio("input/telhados.wav")
song.load()
song_resampled = song.resample(sample_rate=250)
song_resampled.make_spectrogram().plot.contours(['bone', 'BuPu'])

# %%
song_resampled.make_spectrogram().plot(size_cm=[18, 13], margin_cm=2, save=True).contours(['bone', 'BuPu'])
